# %%
import wandb
import os
from dotenv import load_dotenv
# wandb.login()
wandb.login(key=os.environ['WANDB_KEY'])
# wandb.init(project="unifall_train",
#            name='run1',
#            sync_tensorboard=True,
#            )
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /home/eduardo/.netrc
# True

# %%
# !python train.py --img 640 --batch 24 --patience 20 --data /run/media/eduardo/SSD/Unifall/dataset/T-set/Tset_yolov5/data.yaml --weights yolov5s.pt --cache
# Out:
# wandb: Currently logged in as: eduardodut (use `wandb login --relogin` to force relogin)
# train: weights=yolov5s.pt, cfg=, data=/run/media/eduardo/SSD/Unifall/dataset/T-set/Tset_yolov5/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=300, batch_size=24, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=20, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/eduardodut/yolov5 ✅
# YOLOv5 🚀 v6.1-184-g9d8ed37 torch 1.11.0+cu113 CUDA:0 (NVIDIA GeForce RTX 3060 Ti, 7979MiB)
#
# ...
